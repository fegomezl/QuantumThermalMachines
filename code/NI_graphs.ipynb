# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Energy10 = pd.read_csv('../results/energy_10.csv')
Energy20 = pd.read_csv('../results/energy_20.csv')
Energy30 = pd.read_csv('../results/energy_30.csv')
Energy40 = pd.read_csv('../results/energy_40.csv')
Energy50 = pd.read_csv('../results/energy_50.csv')
Energy60 = pd.read_csv('../results/energy_60.csv')
Energy70 = pd.read_csv('../results/energy_70.csv')
Energy80 = pd.read_csv('../results/energy_80.csv')
Energy90 = pd.read_csv('../results/energy_90.csv')
Energy100 = pd.read_csv('../results/energy_100.csv')
Energy110 = pd.read_csv('../results/energy_110.csv')
Energy120 = pd.read_csv('../results/energy_120.csv')
Energy130 = pd.read_csv('../results/energy_130.csv')
Energy140 = pd.read_csv('../results/energy_140.csv')
Energy150 = pd.read_csv('../results/energy_150.csv')
Energy160 = pd.read_csv('../results/energy_160.csv')
Energy170 = pd.read_csv('../results/energy_170.csv')
Energy180 = pd.read_csv('../results/energy_180.csv')
Energy190 = pd.read_csv('../results/energy_190.csv')
Energy200 = pd.read_csv('../results/energy_200.csv')

Temp10 = pd.read_csv('../results/temp_10.csv')
Temp20 = pd.read_csv('../results/temp_20.csv')
Temp30 = pd.read_csv('../results/temp_30.csv')
Temp40 = pd.read_csv('../results/temp_40.csv')
Temp50 = pd.read_csv('../results/temp_50.csv')
Temp60 = pd.read_csv('../results/temp_60.csv')
Temp70 = pd.read_csv('../results/temp_70.csv')
Temp80 = pd.read_csv('../results/temp_80.csv')
Temp90 = pd.read_csv('../results/temp_90.csv')
Temp100 = pd.read_csv('../results/temp_100.csv')
Temp110 = pd.read_csv('../results/temp_110.csv')
Temp120 = pd.read_csv('../results/temp_120.csv')
Temp130 = pd.read_csv('../results/temp_130.csv')
Temp140 = pd.read_csv('../results/temp_140.csv')
Temp150 = pd.read_csv('../results/temp_150.csv')
Temp160 = pd.read_csv('../results/temp_160.csv')
Temp170 = pd.read_csv('../results/temp_170.csv')
Temp180 = pd.read_csv('../results/temp_180.csv')
Temp190 = pd.read_csv('../results/temp_190.csv')
Temp200 = pd.read_csv('../results/temp_200.csv')

Gamma10 = pd.read_csv('../results/gamma_10.csv')
Gamma20 = pd.read_csv('../results/gamma_20.csv')
Gamma30 = pd.read_csv('../results/gamma_30.csv')
Gamma40 = pd.read_csv('../results/gamma_40.csv')
Gamma50 = pd.read_csv('../results/gamma_50.csv')
Gamma60 = pd.read_csv('../results/gamma_60.csv')
Gamma70 = pd.read_csv('../results/gamma_70.csv')
Gamma80 = pd.read_csv('../results/gamma_80.csv')
Gamma90 = pd.read_csv('../results/gamma_90.csv')
Gamma100 = pd.read_csv('../results/gamma_100.csv')
Gamma110 = pd.read_csv('../results/gamma_110.csv')
Gamma120 = pd.read_csv('../results/gamma_120.csv')
Gamma130 = pd.read_csv('../results/gamma_130.csv')
Gamma140 = pd.read_csv('../results/gamma_140.csv')
Gamma150 = pd.read_csv('../results/gamma_150.csv')
Gamma160 = pd.read_csv('../results/gamma_160.csv')
Gamma170 = pd.read_csv('../results/gamma_170.csv')
Gamma180 = pd.read_csv('../results/gamma_180.csv')
Gamma190 = pd.read_csv('../results/gamma_190.csv')
Gamma200 = pd.read_csv('../results/gamma_200.csv')

# %%
plt.rcParams['figure.dpi'] = 150
plt.rcParams['figure.figsize'] = (10, 5)

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3)

colors = plt.cm.cividis_r(np.linspace(0,1,20))

#------------------------------------------------------------------

ax1.plot(Energy10['ϵ'], Energy10['Jₚ'], color=colors[0])
ax1.plot(Energy20['ϵ'], Energy20['Jₚ'], color=colors[1])
ax1.plot(Energy30['ϵ'], Energy30['Jₚ'], color=colors[2])
ax1.plot(Energy40['ϵ'], Energy40['Jₚ'], color=colors[3])
ax1.plot(Energy50['ϵ'], Energy50['Jₚ'], color=colors[4])
ax1.plot(Energy60['ϵ'], Energy60['Jₚ'], color=colors[5])
ax1.plot(Energy70['ϵ'], Energy70['Jₚ'], color=colors[6])
ax1.plot(Energy80['ϵ'], Energy80['Jₚ'], color=colors[7])
ax1.plot(Energy90['ϵ'], Energy90['Jₚ'], color=colors[8])
ax1.plot(Energy100['ϵ'], Energy100['Jₚ'], color=colors[9])
ax1.plot(Energy110['ϵ'], Energy110['Jₚ'], color=colors[10])
ax1.plot(Energy120['ϵ'], Energy120['Jₚ'], color=colors[11])
ax1.plot(Energy130['ϵ'], Energy130['Jₚ'], color=colors[12])
ax1.plot(Energy140['ϵ'], Energy140['Jₚ'], color=colors[13])
ax1.plot(Energy150['ϵ'], Energy150['Jₚ'], color=colors[14])
ax1.plot(Energy160['ϵ'], Energy160['Jₚ'], color=colors[15])
ax1.plot(Energy170['ϵ'], Energy170['Jₚ'], color=colors[16])
ax1.plot(Energy180['ϵ'], Energy180['Jₚ'], color=colors[17])
ax1.plot(Energy190['ϵ'], Energy190['Jₚ'], color=colors[18])
ax1.plot(Energy200['ϵ'], Energy200['Jₚ'], color=colors[19])

ax1.grid()
ax1.set_xlim(-1,1)
ax1.set_ylim(0, 0.012)
ax1.set_ylabel(r'Particle Current Jₚ')
ax1.set_xlabel(r'Single level energy ϵ')
               
#------------------------------------------------------------------

ax2.plot(Temp10['T'], Temp10['Jₚ'], color=colors[0])
ax2.plot(Temp20['T'], Temp20['Jₚ'], color=colors[1])
ax2.plot(Temp30['T'], Temp30['Jₚ'], color=colors[2])
ax2.plot(Temp40['T'], Temp40['Jₚ'], color=colors[3])
ax2.plot(Temp50['T'], Temp50['Jₚ'], color=colors[4])
ax2.plot(Temp60['T'], Temp60['Jₚ'], color=colors[5])
ax2.plot(Temp70['T'], Temp70['Jₚ'], color=colors[6])
ax2.plot(Temp80['T'], Temp80['Jₚ'], color=colors[7])
ax2.plot(Temp90['T'], Temp90['Jₚ'], color=colors[8])
ax2.plot(Temp100['T'], Temp100['Jₚ'], color=colors[9])
ax2.plot(Temp110['T'], Temp110['Jₚ'], color=colors[10])
ax2.plot(Temp120['T'], Temp120['Jₚ'], color=colors[11])
ax2.plot(Temp130['T'], Temp130['Jₚ'], color=colors[12])
ax2.plot(Temp140['T'], Temp140['Jₚ'], color=colors[13])
ax2.plot(Temp150['T'], Temp150['Jₚ'], color=colors[14])
ax2.plot(Temp160['T'], Temp160['Jₚ'], color=colors[15])
ax2.plot(Temp170['T'], Temp170['Jₚ'], color=colors[16])
ax2.plot(Temp180['T'], Temp180['Jₚ'], color=colors[17])
ax2.plot(Temp190['T'], Temp190['Jₚ'], color=colors[18])
ax2.plot(Temp200['T'], Temp200['Jₚ'], color=colors[19])
               
ax2.grid()
ax2.set_xlim(1e-4,1e1)
ax2.set_ylim(0, 0.012)
ax2.set_xlabel('Temperature T')
ax2.set_xscale('log')

#------------------------------------------------------------------

ax3.plot(Gamma10['Γ'], Gamma10['Jₚ'], color=colors[0])
ax3.plot(Gamma20['Γ'], Gamma20['Jₚ'], color=colors[1])
ax3.plot(Gamma30['Γ'], Gamma30['Jₚ'], color=colors[2])
ax3.plot(Gamma40['Γ'], Gamma40['Jₚ'], color=colors[3])
ax3.plot(Gamma50['Γ'], Gamma50['Jₚ'], color=colors[4])
ax3.plot(Gamma60['Γ'], Gamma60['Jₚ'], color=colors[5])
ax3.plot(Gamma70['Γ'], Gamma70['Jₚ'], color=colors[6])
ax3.plot(Gamma80['Γ'], Gamma80['Jₚ'], color=colors[7])
ax3.plot(Gamma90['Γ'], Gamma90['Jₚ'], color=colors[8])
ax3.plot(Gamma100['Γ'], Gamma100['Jₚ'], color=colors[9])
ax3.plot(Gamma110['Γ'], Gamma110['Jₚ'], color=colors[10])
ax3.plot(Gamma120['Γ'], Gamma120['Jₚ'], color=colors[11])
ax3.plot(Gamma130['Γ'], Gamma130['Jₚ'], color=colors[12])
ax3.plot(Gamma140['Γ'], Gamma140['Jₚ'], color=colors[13])
ax3.plot(Gamma150['Γ'], Gamma150['Jₚ'], color=colors[14])
ax3.plot(Gamma160['Γ'], Gamma160['Jₚ'], color=colors[15])
ax3.plot(Gamma170['Γ'], Gamma170['Jₚ'], color=colors[16])
ax3.plot(Gamma180['Γ'], Gamma180['Jₚ'], color=colors[17])
ax3.plot(Gamma190['Γ'], Gamma190['Jₚ'], color=colors[18])
ax3.plot(Gamma200['Γ'], Gamma200['Jₚ'], color=colors[19])
               
ax3.grid()
ax3.set_xlim(0, 0.5)
ax3.set_ylim(0, 0.018)
ax3.set_xlabel(r'System-lead coupling Γ')
               
#------------------------------------------------------------------

cbar = fig.colorbar(plt.cm.ScalarMappable(cmap='cividis_r'), ax=ax3, 
                    ticks=[n/10 for n in range(0,11)])
cbar.ax.set_yticklabels([str(20*n) for n in range(0,11)])  
cbar.set_label('L')

fig.tight_layout()
plt.show()

# %%
fig, (ax1,ax2,ax3) = plt.subplots(1,3)

colors = plt.cm.inferno_r(np.linspace(0,1,20))

#------------------------------------------------------------------

ax1.plot(Energy10['ϵ'], Energy10['Jₕ'], color=colors[0])
ax1.plot(Energy20['ϵ'], Energy20['Jₕ'], color=colors[1])
ax1.plot(Energy30['ϵ'], Energy30['Jₕ'], color=colors[2])
ax1.plot(Energy40['ϵ'], Energy40['Jₕ'], color=colors[3])
ax1.plot(Energy50['ϵ'], Energy50['Jₕ'], color=colors[4])
ax1.plot(Energy60['ϵ'], Energy60['Jₕ'], color=colors[5])
ax1.plot(Energy70['ϵ'], Energy70['Jₕ'], color=colors[6])
ax1.plot(Energy80['ϵ'], Energy80['Jₕ'], color=colors[7])
ax1.plot(Energy90['ϵ'], Energy90['Jₕ'], color=colors[8])
ax1.plot(Energy100['ϵ'], Energy100['Jₕ'], color=colors[9])
ax1.plot(Energy110['ϵ'], Energy110['Jₕ'], color=colors[10])
ax1.plot(Energy120['ϵ'], Energy120['Jₕ'], color=colors[11])
ax1.plot(Energy130['ϵ'], Energy130['Jₕ'], color=colors[12])
ax1.plot(Energy140['ϵ'], Energy140['Jₕ'], color=colors[13])
ax1.plot(Energy150['ϵ'], Energy150['Jₕ'], color=colors[14])
ax1.plot(Energy160['ϵ'], Energy160['Jₕ'], color=colors[15])
ax1.plot(Energy170['ϵ'], Energy170['Jₕ'], color=colors[16])
ax1.plot(Energy180['ϵ'], Energy180['Jₕ'], color=colors[17])
ax1.plot(Energy190['ϵ'], Energy190['Jₕ'], color=colors[18])
ax1.plot(Energy200['ϵ'], Energy200['Jₕ'], color=colors[19])

ax1.grid()
ax1.set_xlim(-1,1)
ax1.set_ylim(-1e-3, 1e-3)
ax1.set_ylabel(r'Energy Current Jₕ')
ax1.set_xlabel(r'Single level energy ϵ')
               
#------------------------------------------------------------------

ax2.plot(Temp10['T'], Temp10['Jₕ'], color=colors[0])
ax2.plot(Temp20['T'], Temp20['Jₕ'], color=colors[1])
ax2.plot(Temp30['T'], Temp30['Jₕ'], color=colors[2])
ax2.plot(Temp40['T'], Temp40['Jₕ'], color=colors[3])
ax2.plot(Temp50['T'], Temp50['Jₕ'], color=colors[4])
ax2.plot(Temp60['T'], Temp60['Jₕ'], color=colors[5])
ax2.plot(Temp70['T'], Temp70['Jₕ'], color=colors[6])
ax2.plot(Temp80['T'], Temp80['Jₕ'], color=colors[7])
ax2.plot(Temp90['T'], Temp90['Jₕ'], color=colors[8])
ax2.plot(Temp100['T'], Temp100['Jₕ'], color=colors[9])
ax2.plot(Temp110['T'], Temp110['Jₕ'], color=colors[10])
ax2.plot(Temp120['T'], Temp120['Jₕ'], color=colors[11])
ax2.plot(Temp130['T'], Temp130['Jₕ'], color=colors[12])
ax2.plot(Temp140['T'], Temp140['Jₕ'], color=colors[13])
ax2.plot(Temp150['T'], Temp150['Jₕ'], color=colors[14])
ax2.plot(Temp160['T'], Temp160['Jₕ'], color=colors[15])
ax2.plot(Temp170['T'], Temp170['Jₕ'], color=colors[16])
ax2.plot(Temp180['T'], Temp180['Jₕ'], color=colors[17])
ax2.plot(Temp190['T'], Temp190['Jₕ'], color=colors[18])
ax2.plot(Temp200['T'], Temp200['Jₕ'], color=colors[19])
               
ax2.grid()
ax2.set_xlim(1e-4,1e1)
ax2.set_ylim(0, 8e-4)
ax2.set_xlabel('Temperature T')
ax2.set_xscale('log')

#------------------------------------------------------------------

ax3.plot(Gamma10['Γ'], Gamma10['Jₕ'], color=colors[0])
ax3.plot(Gamma20['Γ'], Gamma20['Jₕ'], color=colors[1])
ax3.plot(Gamma30['Γ'], Gamma30['Jₕ'], color=colors[2])
ax3.plot(Gamma40['Γ'], Gamma40['Jₕ'], color=colors[3])
ax3.plot(Gamma50['Γ'], Gamma50['Jₕ'], color=colors[4])
ax3.plot(Gamma60['Γ'], Gamma60['Jₕ'], color=colors[5])
ax3.plot(Gamma70['Γ'], Gamma70['Jₕ'], color=colors[6])
ax3.plot(Gamma80['Γ'], Gamma80['Jₕ'], color=colors[7])
ax3.plot(Gamma90['Γ'], Gamma90['Jₕ'], color=colors[8])
ax3.plot(Gamma100['Γ'], Gamma100['Jₕ'], color=colors[9])
ax3.plot(Gamma110['Γ'], Gamma110['Jₕ'], color=colors[10])
ax3.plot(Gamma120['Γ'], Gamma120['Jₕ'], color=colors[11])
ax3.plot(Gamma130['Γ'], Gamma130['Jₕ'], color=colors[12])
ax3.plot(Gamma140['Γ'], Gamma140['Jₕ'], color=colors[13])
ax3.plot(Gamma150['Γ'], Gamma150['Jₕ'], color=colors[14])
ax3.plot(Gamma160['Γ'], Gamma160['Jₕ'], color=colors[15])
ax3.plot(Gamma170['Γ'], Gamma170['Jₕ'], color=colors[16])
ax3.plot(Gamma180['Γ'], Gamma180['Jₕ'], color=colors[17])
ax3.plot(Gamma190['Γ'], Gamma190['Jₕ'], color=colors[18])
ax3.plot(Gamma200['Γ'], Gamma200['Jₕ'], color=colors[19])
               
ax3.grid()
ax3.set_xlim(0, 0.5)
ax3.set_ylim(0, 8e-4)
ax3.set_xlabel(r'System-lead coupling Γ')
               
#------------------------------------------------------------------

cbar = fig.colorbar(plt.cm.ScalarMappable(cmap='inferno_r'), ax=ax3, 
                    ticks=[n/10 for n in range(0,11)])
cbar.ax.set_yticklabels([str(20*n) for n in range(0,11)])  
cbar.set_label('L')

fig.tight_layout()
plt.show()
